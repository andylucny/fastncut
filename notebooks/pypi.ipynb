# %%
# clone
# !git clone --depth 1 --filter=blob:none --sparse https://github.com/andylucny/fastncut.git
# %cd fastncut
# !git sparse-checkout set fastncut pyproject.toml
# Out:
# fatal: destination path 'fastncut' already exists and is not an empty directory.
# /content/fastncut/fastncut

# %%
# install build tools
# !pip install --upgrade build
# Out:
# Collecting build
#   Downloading build-1.4.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from build) (26.0)
# Collecting pyproject_hooks (from build)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Downloading build-1.4.2-py3-none-any.whl (24 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Installing collected packages: pyproject_hooks, build
# Successfully installed build-1.4.2 pyproject_hooks-1.2.0

# %%
# build
# %cd ..
# !python -m build
# Out:
# /content/fastncut
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools>=61.0
# * Getting build dependencies for sdist...
# running egg_info
# creating my_package.egg-info
# writing my_package.egg-info/PKG-INFO
# writing dependency_links to my_package.egg-info/dependency_links.txt
# writing top-level names to my_package.egg-info/top_level.txt
# writing manifest file 'my_package.egg-info/SOURCES.txt'
# reading manifest file 'my_package.egg-info/SOURCES.txt'
# writing manifest file 'my_package.egg-info/SOURCES.txt'
# * Building sdist...
# running sdist
# running egg_info
# writing my_package.egg-info/PKG-INFO
# writing dependency_links to my_package.egg-info/dependency_links.txt
# writing top-level names to my_package.egg-info/top_level.txt
# reading manifest file 'my_package.egg-info/SOURCES.txt'
# writing manifest file 'my_package.egg-info/SOURCES.txt'
# warning: sdist: standard file not found: should have one of README, README.rst, README.txt, README.md
#
# running check
# creating my_package-0.1.0
# creating my_package-0.1.0/fastncut
# creating my_package-0.1.0/my_package.egg-info
# copying files to my_package-0.1.0...
# copying pyproject.toml -> my_package-0.1.0
# copying fastncut/__init__.py -> my_package-0.1.0/fastncut
# copying fastncut/fastncut.py -> my_package-0.1.0/fastncut
# copying my_package.egg-info/PKG-INFO -> my_package-0.1.0/my_package.egg-info
# copying my_package.egg-info/SOURCES.txt -> my_package-0.1.0/my_package.egg-info
# copying my_package.egg-info/dependency_links.txt -> my_package-0.1.0/my_package.egg-info
# copying my_package.egg-info/top_level.txt -> my_package-0.1.0/my_package.egg-info
# copying my_package.egg-info/SOURCES.txt -> my_package-0.1.0/my_package.egg-info
# Writing my_package-0.1.0/setup.cfg
# Creating tar archive
# removing 'my_package-0.1.0' (and everything under it)
# * Building wheel from sdist
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools>=61.0
# * Getting build dependencies for wheel...
# running egg_info
# writing my_package.egg-info/PKG-INFO
# writing dependency_links to my_package.egg-info/dependency_links.txt
# writing top-level names to my_package.egg-info/top_level.txt
# reading manifest file 'my_package.egg-info/SOURCES.txt'
# writing manifest file 'my_package.egg-info/SOURCES.txt'
# * Building wheel...
# running bdist_wheel
# running build
# running build_py
# creating build/lib/fastncut
# copying fastncut/fastncut.py -> build/lib/fastncut
# copying fastncut/__init__.py -> build/lib/fastncut
# running egg_info
# writing my_package.egg-info/PKG-INFO
# writing dependency_links to my_package.egg-info/dependency_links.txt
# writing top-level names to my_package.egg-info/top_level.txt
# reading manifest file 'my_package.egg-info/SOURCES.txt'
# writing manifest file 'my_package.egg-info/SOURCES.txt'
# installing to build/bdist.linux-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.linux-x86_64/wheel
# creating build/bdist.linux-x86_64/wheel/fastncut
# copying build/lib/fastncut/fastncut.py -> build/bdist.linux-x86_64/wheel/./fastncut
# copying build/lib/fastncut/__init__.py -> build/bdist.linux-x86_64/wheel/./fastncut
# running install_egg_info
# Copying my_package.egg-info to build/bdist.linux-x86_64/wheel/./my_package-0.1.0-py3.12.egg-info
# running install_scripts
# creating build/bdist.linux-x86_64/wheel/my_package-0.1.0.dist-info/WHEEL
# creating '/content/fastncut/dist/.tmp-xwhwv5h6/my_package-0.1.0-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
# adding 'fastncut/__init__.py'
# adding 'fastncut/fastncut.py'
# adding 'my_package-0.1.0.dist-info/METADATA'
# adding 'my_package-0.1.0.dist-info/WHEEL'
# adding 'my_package-0.1.0.dist-info/top_level.txt'
# adding 'my_package-0.1.0.dist-info/RECORD'
# removing build/bdist.linux-x86_64/wheel
# Successfully built my_package-0.1.0.tar.gz and my_package-0.1.0-py3-none-any.whl

# %%
# !ls -l dist
# Out:
# total 16
# -rw-r--r-- 1 root root 6649 Mar 26 23:29 my_package-0.1.0-py3-none-any.whl
# -rw-r--r-- 1 root root 6228 Mar 26 23:29 my_package-0.1.0.tar.gz

# %%
# test
# !pip install dist/my_package-0.1.0-py3-none-any.whl

# %%
# install publish tools
# !pip install twine

# %%
# publish
# !twine upload --repository fastncut dist/*

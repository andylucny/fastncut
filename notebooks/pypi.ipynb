# %%
# clone
git clone --depth 1 --filter=blob:none --sparse https://github.com/your-username/fastncut.git
cd fastncut
git sparse-checkout set fastncut

# %%
# install build tools
pip install --upgrade build

# %%
# build
python -m build

# %%
# !ls -l dist

# %%
# test
pip install dist/my_package-0.1.0-py3-none-any.whl

# %%
# install publish tools
pip install twine

# %%
# publish
twine upload --repository fastncut dist/*

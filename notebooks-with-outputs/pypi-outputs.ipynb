# %%
# clone
# !git clone --depth 1 --filter=blob:none --sparse https://github.com/andylucny/fastncut.git
# %cd fastncut
# !git sparse-checkout set fastncut pyproject.toml
# Out:
# Cloning into 'fastncut'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), 3.74 KiB | 3.74 MiB/s, done.
# /content/fastncut
# remote: Enumerating objects: 2, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 2 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (2/2), 5.28 KiB | 5.28 MiB/s, done.

# %%
# install build tools
# !pip install --upgrade build
# Out:
# Collecting build
#   Downloading build-1.4.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from build) (26.0)
# Collecting pyproject_hooks (from build)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Downloading build-1.4.2-py3-none-any.whl (24 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Installing collected packages: pyproject_hooks, build
# Successfully installed build-1.4.2 pyproject_hooks-1.2.0

# %%
# build
# %cd /content/fastncut
# !python -m build
# Out:
# /content/fastncut
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools>=61.0
# * Getting build dependencies for sdist...
# /tmp/build-env-fpwv79nv/lib/python3.12/site-packages/setuptools/config/expand.py:128: SetuptoolsWarning: File '/content/fastncut/README.md' cannot be found
#   for path in _filter_existing_files(_filepaths)
# running egg_info
# creating fastncut.egg-info
# writing fastncut.egg-info/PKG-INFO
# writing dependency_links to fastncut.egg-info/dependency_links.txt
# writing top-level names to fastncut.egg-info/top_level.txt
# writing manifest file 'fastncut.egg-info/SOURCES.txt'
# reading manifest file 'fastncut.egg-info/SOURCES.txt'
# writing manifest file 'fastncut.egg-info/SOURCES.txt'
# * Building sdist...
# /tmp/build-env-fpwv79nv/lib/python3.12/site-packages/setuptools/config/expand.py:128: SetuptoolsWarning: File '/content/fastncut/README.md' cannot be found
#   for path in _filter_existing_files(_filepaths)
# running sdist
# running egg_info
# writing fastncut.egg-info/PKG-INFO
# writing dependency_links to fastncut.egg-info/dependency_links.txt
# writing top-level names to fastncut.egg-info/top_level.txt
# reading manifest file 'fastncut.egg-info/SOURCES.txt'
# writing manifest file 'fastncut.egg-info/SOURCES.txt'
# warning: sdist: standard file not found: should have one of README, README.rst, README.txt, README.md
#
# running check
# creating fastncut-2.0.2
# creating fastncut-2.0.2/fastncut
# creating fastncut-2.0.2/fastncut.egg-info
# copying files to fastncut-2.0.2...
# copying pyproject.toml -> fastncut-2.0.2
# copying fastncut/__init__.py -> fastncut-2.0.2/fastncut
# copying fastncut/fastncut.py -> fastncut-2.0.2/fastncut
# copying fastncut.egg-info/PKG-INFO -> fastncut-2.0.2/fastncut.egg-info
# copying fastncut.egg-info/SOURCES.txt -> fastncut-2.0.2/fastncut.egg-info
# copying fastncut.egg-info/dependency_links.txt -> fastncut-2.0.2/fastncut.egg-info
# copying fastncut.egg-info/top_level.txt -> fastncut-2.0.2/fastncut.egg-info
# copying fastncut.egg-info/SOURCES.txt -> fastncut-2.0.2/fastncut.egg-info
# Writing fastncut-2.0.2/setup.cfg
# Creating tar archive
# removing 'fastncut-2.0.2' (and everything under it)
# * Building wheel from sdist
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools>=61.0
# * Getting build dependencies for wheel...
# /tmp/build-env-_4sptozt/lib/python3.12/site-packages/setuptools/config/expand.py:128: SetuptoolsWarning: File '/tmp/build-via-sdist-x1ns9cu0/fastncut-2.0.2/README.md' cannot be found
#   for path in _filter_existing_files(_filepaths)
# running egg_info
# writing fastncut.egg-info/PKG-INFO
# writing dependency_links to fastncut.egg-info/dependency_links.txt
# writing top-level names to fastncut.egg-info/top_level.txt
# reading manifest file 'fastncut.egg-info/SOURCES.txt'
# writing manifest file 'fastncut.egg-info/SOURCES.txt'
# * Building wheel...
# /tmp/build-env-_4sptozt/lib/python3.12/site-packages/setuptools/config/expand.py:128: SetuptoolsWarning: File '/tmp/build-via-sdist-x1ns9cu0/fastncut-2.0.2/README.md' cannot be found
#   for path in _filter_existing_files(_filepaths)
# running bdist_wheel
# running build
# running build_py
# creating build/lib/fastncut
# copying fastncut/__init__.py -> build/lib/fastncut
# copying fastncut/fastncut.py -> build/lib/fastncut
# running egg_info
# writing fastncut.egg-info/PKG-INFO
# writing dependency_links to fastncut.egg-info/dependency_links.txt
# writing top-level names to fastncut.egg-info/top_level.txt
# reading manifest file 'fastncut.egg-info/SOURCES.txt'
# writing manifest file 'fastncut.egg-info/SOURCES.txt'
# installing to build/bdist.linux-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.linux-x86_64/wheel
# creating build/bdist.linux-x86_64/wheel/fastncut
# copying build/lib/fastncut/__init__.py -> build/bdist.linux-x86_64/wheel/./fastncut
# copying build/lib/fastncut/fastncut.py -> build/bdist.linux-x86_64/wheel/./fastncut
# running install_egg_info
# Copying fastncut.egg-info to build/bdist.linux-x86_64/wheel/./fastncut-2.0.2-py3.12.egg-info
# running install_scripts
# creating build/bdist.linux-x86_64/wheel/fastncut-2.0.2.dist-info/WHEEL
# creating '/content/fastncut/dist/.tmp-b71x3_k2/fastncut-2.0.2-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
# adding 'fastncut/__init__.py'
# adding 'fastncut/fastncut.py'
# adding 'fastncut-2.0.2.dist-info/METADATA'
# adding 'fastncut-2.0.2.dist-info/WHEEL'
# adding 'fastncut-2.0.2.dist-info/top_level.txt'
# adding 'fastncut-2.0.2.dist-info/RECORD'
# removing build/bdist.linux-x86_64/wheel
# Successfully built fastncut-2.0.2.tar.gz and fastncut-2.0.2-py3-none-any.whl

# %%
# !ls -l dist
# Out:
# total 16
# -rw-r--r-- 1 root root 6841 Mar 29 14:02 fastncut-2.0.2-py3-none-any.whl
# -rw-r--r-- 1 root root 6446 Mar 29 14:02 fastncut-2.0.2.tar.gz

# %%
import tomllib

with open("pyproject.toml", "rb") as f:
    data = tomllib.load(f)

version = data["project"]["version"]
print(version)  # "2.0.1"
# Out:
# 2.0.2

# %%
# !echo dist/fastncut-{version}-py3-none-any.whl
# Out:
# dist/fastncut-2.0.2-py3-none-any.whl

# %%
# test
# !pip install dist/fastncut-{version}-py3-none-any.whl
# Out:
# Processing ./dist/fastncut-2.0.2-py3-none-any.whl
# Installing collected packages: fastncut
# Successfully installed fastncut-2.0.2

# %%
# test
import fastncut

# %%
fastncut.__version__
# Out:
# '2.0.2'

# %%
# install publish tools
# !pip install twine
# Out:
# Collecting twine
#   Downloading twine-6.2.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting readme-renderer>=35.0 (from twine)
#   Downloading readme_renderer-44.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.12/dist-packages (from twine) (2.32.4)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from twine) (1.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from twine) (2.5.0)
# Requirement already satisfied: keyring>=21.2.0 in /usr/local/lib/python3.12/dist-packages (from twine) (25.7.0)
# Collecting rfc3986>=1.4.0 (from twine)
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from twine) (13.9.4)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from twine) (26.0)
# Collecting id (from twine)
#   Downloading id-1.6.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=21.2.0->twine) (3.5.0)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=21.2.0->twine) (0.9.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.12/dist-packages (from keyring>=21.2.0->twine) (3.4.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.12/dist-packages (from keyring>=21.2.0->twine) (4.4.0)
# Requirement already satisfied: jaraco.context in /usr/local/lib/python3.12/dist-packages (from keyring>=21.2.0->twine) (6.1.1)
# Collecting nh3>=0.2.14 (from readme-renderer>=35.0->twine)
#   Downloading nh3-0.3.4-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: docutils>=0.21.2 in /usr/local/lib/python3.12/dist-packages (from readme-renderer>=35.0->twine) (0.21.2)
# Requirement already satisfied: Pygments>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from readme-renderer>=35.0->twine) (2.19.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->twine) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->twine) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->twine) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.0.0->twine) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->twine) (0.1.2)
# Requirement already satisfied: cryptography>=2.0 in /usr/local/lib/python3.12/dist-packages (from SecretStorage>=3.2->keyring>=21.2.0->twine) (43.0.3)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from jaraco.classes->keyring>=21.2.0->twine) (10.8.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring>=21.2.0->twine) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring>=21.2.0->twine) (3.0)
# Downloading twine-6.2.0-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 2.4 MB/s eta 0:00:00
# Downloading readme_renderer-44.0-py3-none-any.whl (13 kB)
# Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Downloading id-1.6.1-py3-none-any.whl (14 kB)
# Downloading nh3-0.3.4-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (804 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.0/805.0 kB 18.4 MB/s eta 0:00:00
# Installing collected packages: rfc3986, nh3, id, readme-renderer, twine
# Successfully installed id-1.6.1 nh3-0.3.4 readme-renderer-44.0 rfc3986-2.0.0 twine-6.2.0

# %%
# !ls -l
# Out:
# total 20
# drwxr-xr-x 2 root root 4096 Mar 29 14:02 dist
# drwxr-xr-x 3 root root 4096 Mar 29 14:03 fastncut
# drwxr-xr-x 2 root root 4096 Mar 29 14:02 fastncut.egg-info
# -rw-r--r-- 1 root root  181 Mar 29 14:02 pypi_api_token.txt
# -rw-r--r-- 1 root root  531 Mar 29 13:31 pyproject.toml

# %%
# !echo "copy pypi_api_token.txt into /content/fastncut"
# Out:
# copy pypi_api_token.txt into /content/fastncut

# %%
with open("/content/fastncut/pypi_api_token.txt") as f:
    PYPI_API_TOKEN = f.readline()[:-1].strip()

# %%
# !twine upload -u __token__ -p "$PYPI_API_TOKEN" --repository-url https://upload.pypi.org/legacy/ dist/* --verbose
# Out:
# Uploading distributions to https://upload.pypi.org/legacy/
# INFO     dist/fastncut-2.0.2-py3-none-any.whl (6.7 KB)
# INFO     dist/fastncut-2.0.2.tar.gz (6.3 KB)
# INFO     username set by command options
# INFO     password set by command options
# INFO     username: __token__
# INFO     password: <hidden>
# Uploading fastncut-2.0.2-py3-none-any.whl
# 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 kB • 00:00 • ?
# INFO     Response from https://upload.pypi.org/legacy/:
#          200 OK
# INFO     <html>
#           <head>
#            <title>200 OK</title>
#           </head>
#           <body>
#            <h1>200 OK</h1>
#            <br/><br/>
#
#
#
#           </body>
#          </html>
# Uploading fastncut-2.0.2.tar.gz
# 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 kB • 00:00 • ?
# INFO     Response from https://upload.pypi.org/legacy/:
#          200 OK
# INFO     <html>
#           <head>
#            <title>200 OK</title>
#           </head>
#           <body>
#            <h1>200 OK</h1>
#            <br/><br/>
#
#
#
#           </body>
#          </html>
#
# View at:
# https://pypi.org/project/fastncut/2.0.2/
